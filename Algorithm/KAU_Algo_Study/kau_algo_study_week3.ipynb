# %% [markdown]
# # 러닝크루 3주차

# %% [markdown]
# ## [주사위 세개(2480)](https://www.acmicpc.net/problem/2480)

# %% [markdown]
# ## [벼락치기(23739)](https://www.acmicpc.net/problem/23739)

# %% [markdown]
# ## [아기 상어(16236)](https://www.acmicpc.net/problem/16236)

# %% [markdown]
# ## [검열(3111)](https://www.acmicpc.net/problem/3111)
